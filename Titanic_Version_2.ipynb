# %% [markdown]
# I will be looking at a dataset containng information about the passengers on the Titanic.

# %%
import pandas as pd

titanic = pd.read_excel (r'C:\Users\jeffery.peterson.tm\Documents\School\Classes\DSC 530\Final Project\Titanic\titanic_complete.xls')

# %%
titanic.head(n=5)
# Out:
#    pclass  survived                              name     sex   age  sibsp  \
# 0       3         0               Abbing, Mr. Anthony    male  42.0      0
# 1       3         0     Abbott, Master. Eugene Joseph    male  13.0      0
# 2       3         0       Abbott, Mr. Rossmore Edward    male  16.0      1
# 3       3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1
# 4       3         1       Abelseth, Miss. Karen Marie  female  16.0      0
#
#    parch     ticket   fare cabin embarked boat   body               home.dest
# 0      0  C.A. 5547   7.55   NaN        S  NaN    NaN                     NaN
# 1      2  C.A. 2673  20.25   NaN        S  NaN    NaN     East Providence, RI
# 2      1  C.A. 2673  20.25   NaN        S  NaN  190.0     East Providence, RI
# 3      1  C.A. 2673  20.25   NaN        S    A    NaN     East Providence, RI
# 4      0     348125   7.65   NaN        S   16    NaN  Norway Los Angeles, CA

# %% [markdown]
# This dataset contains 14 variables. Of these, I am going to look at the following: pclass - passenger class (1=1st, 2=2nd, 3=3rd), survived - did the passenger survive (0=No, 1=Yes), sex - gender of the passenger, age - age of the passenger, fare - price passenger paid for ticket (British Pounds)
#
# I am selecting these variables because the question I am trying to answer is if I would have been likely to survive the voyage. My plan is to develop a logistic regression model that takes into account all of these variables. I will then substitute my personal information to determine my survivability likelihood. I will convert the fare rate to what the cost would be in today's US Dollar and then determine what a current trans-Atlantic cruise would cost. Based on this, I will make a determination as to how much I am willing to spend on my ticket and therefore, which class I will end up in.
#
# If I was going to expand my variable set, I might want to consider the sibsp (number of siblings/spouses aboard) and the parch (number of parents/children aboard). My thinking is that there could be a couple of scenarios that would be applicable to these variables. For example, a family might want to all die together as opposed to having to choose which member gets to live.

# %%
from __future__ import print_function, division
import os
os.getcwd()
os.chdir("C:/Users/jeffery.peterson.tm/Documents/School/Classes/DSC 530/Week 2/ThinkStats2-master/code/")

# %matplotlib inline
import numpy as np
import thinkstats2
import thinkplot

# %%
hist_pclass = thinkstats2.Hist(titanic.pclass, label="Histogram of Passenger Class")
thinkplot.Hist(hist_pclass)
thinkplot.Show(xlabel="Passenger Class", ylabel="Frequency")

# %%
hist_survived = thinkstats2.Hist(titanic.survived, label="Histogram of Passenger Survival (0=No, 1=Yes)")
thinkplot.Hist(hist_survived)
thinkplot.Show(xlabel="Passenger Survived?", ylabel="Frequency")

# %%
hist_sex = thinkstats2.Hist(titanic.sex, label="Histogram of Passenger Gender")
thinkplot.Hist(hist_sex)
thinkplot.Show(xlabel="Passenger Gender", ylabel="Frequency")

# %%
hist_age = thinkstats2.Hist(titanic.age, label="Histogram of Passenger Age")
thinkplot.Hist(hist_age)
thinkplot.Show(xlabel="Passenger Age", ylabel="Frequency")

# %%
hist_fare = thinkstats2.Hist(titanic.fare, label="Histogram of Passenger Fare")
thinkplot.Hist(hist_fare)
thinkplot.Show(xlabel="Passenger Fare", ylabel="Frequency")

# %% [markdown]
# For some reason, the histogram of fare data is not showing.  I will try a different histogram function.

# %%
titanic.hist(column="fare")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2D94048D0>]],
#       dtype=object)

# %%
for pclass, freq in hist_pclass.Smallest(10):
    print(pclass, freq)
for pclass, freq in hist_pclass.Largest(10):
    print(pclass, freq)
titanic["pclass"].isna().sum()
#No outliers for pclass variable.  This makes sense because we only had three possible categories.
# Out:
# 1 323
# 2 277
# 3 709
# 3 709
# 2 277
# 1 323
# 0

# %%
for survived, freq in hist_survived.Smallest(10):
    print(survived, freq)
for survivesd, freq in hist_survived.Largest(10):
    print(survived, freq)
titanic["survived"].isna().sum()
#No outliers.  They either survived or they didn't.
# Out:
# 0 809
# 1 500
# 1 500
# 1 809
# 0

# %%
for sex, freq in hist_sex.Smallest(10):
    print(sex, freq)
for sex, freq in hist_sex.Largest(10):
    print(sex, freq)
titanic["sex"].isna().sum()
#No outliers.  They were either male or female.
# Out:
# female 466
# male 843
# male 843
# female 466
# 0

# %%
for age, freq in hist_age.Smallest(10):
    print(age, freq)
for age, freq in hist_age.Largest(10):
    print(age, freq)
titanic["age"].isna().sum()
#No apparent outliers.  According to WikiPedia, the youngest person on the Titanic was a two-month old.  If you take 2/12, you get 0.1667.
#The older ages seem resonable as well.
#There are, however, 263 blanks where no age is listed.  While I'm not going to say these are outliers right now, I may adjust things later on.
# Out:
# 0.1667 1
# 0.3333 1
# 0.4167 1
# 0.6667 1
# 0.75 3
# 0.8333 3
# 0.9167 2
# 1.0 10
# 2.0 12
# 3.0 7
# 80.0 1
# 76.0 1
# 74.0 1
# 71.0 2
# 70.5 1
# 70.0 2
# 67.0 1
# 66.0 1
# 65.0 3
# 64.0 5
# 263

# %%
for fare, freq in hist_fare.Smallest(10):
    print(survived, freq)
for fare, freq in hist_fare.Largest(10):
    print(fare, freq)
titanic["fare"].isna().sum()
#The value of 17 is actually for a fare of 0.  Since a value of 0 may cause issues in our analysis later on, I am going to make any 0 fare a value of 1.
#The fare value of 512.3292 is nearly double that of the next highest fare.  Because of this, I am going to reject this value as an outlier.
#There is one blank fare entry.  I am going to substitute this blank value for the mean fare.
# Out:
# 1 17
# 1 1
# 1 1
# 1 1
# 1 1
# 1 3
# 1 1
# 1 3
# 1 2
# 1 1
# 512.3292 4
# 263.0 6
# 262.375 7
# 247.5208 3
# 227.525 5
# 221.7792 4
# 211.5 5
# 211.3375 4
# 164.8667 4
# 153.4625 3
# 1

# %% [markdown]
# The next few cells will deal with correcting the data set.

# %%
import pandas as pd
titanic["fare"]= titanic["fare"].replace(0.0, 1.0)

# %%
titanic.sort_values(by=['fare'])
#The 17 zero fares are now listed as 1.0
# Out:
#       pclass  survived                                               name  \
# 610        3         0                                Johnson, Mr. Alfred
# 190        2         0                              Campbell, Mr. William
# 670        2         0                               Knight, Mr. Robert J
# 1247       2         0                         Watson, Mr. Ennis Hastings
# 935        2         0                        Parkes, Mr. Francis "Frank"
# 936        1         0                      Parr, Mr. William Henry Marsh
# 612        3         0                    Johnson, Mr. William Cahoone Jr
# 426        2         0                   Frost, Mr. Anthony Wood "Archie"
# 1200       3         1                       Tornquist, Mr. William Henry
# 46         1         0                             Andrews, Mr. Thomas Jr
# 427        1         0                                   Fry, Mr. Richard
# 232        1         0              Chisholm, Mr. Roderick Robert Crispin
# 585        1         1                            Ismay, Mr. Joseph Bruce
# 288        2         0                     Cunningham, Mr. Alfred Fleming
# 515        1         0                              Harrison, Mr. William
# 707        3         0                                Leonard, Mr. Lionel
# 997        1         0                    Reuchlin, Jonkheer. John George
# 900        3         1                          Olsen, Master. Artur Karl
# 119        3         0                                Betros, Mr. Tannous
# 202        1         0                           Carlsson, Mr. Frans Olof
# 885        3         0                          Nysveen, Mr. Johan Hansen
# 1185       3         0                              Thomas, Mr. Charles P
# 1186       3         0                                   Thomas, Mr. John
# 703        3         0                         Lemberopolous, Mr. Peter L
# 560        3         0                   Holm, Mr. John Fredrik Alexander
# 1277       3         0                            Wiklund, Mr. Karl Johan
# 602        3         0                         Johanson, Mr. Jakob Alfred
# 1276       3         0                          Wiklund, Mr. Jakob Alfred
# 530        3         0                       Hegarty, Miss. Hanora "Nora"
# 170        3         0                                Burke, Mr. Jeremiah
# ...      ...       ...                                                ...
# 1159       1         0                                 Straus, Mr. Isidor
# 1160       1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 387        1         0                                 Farthing, Mr. John
# 122        1         1                                  Bird, Miss. Ellen
# 68         1         0                             Astor, Col. John Jacob
# 120        1         1                              Bidois, Miss. Rosalie
# 69         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 1018       1         0                                Robbins, Mr. Victor
# 381        1         1                      Endres, Miss. Caroline Louise
# 98         1         0                           Baxter, Mr. Quigg Edmond
# 349        1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 99         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 1048       1         1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 1046       1         1              Ryerson, Miss. Susan Parker "Suzette"
# 227        1         1                        Chaudanson, Miss. Victorine
# 1045       1         1                         Ryerson, Miss. Emily Borie
# 144        1         1                           Bowen, Miss. Grace Scott
# 1044       1         1                        Ryerson, Master. John Borie
# 1047       1         0                         Ryerson, Mr. Arthur Larned
# 411        1         1                         Fortune, Miss. Mabel Helen
# 412        1         0                     Fortune, Mr. Charles Alexander
# 413        1         0                                  Fortune, Mr. Mark
# 410        1         1                         Fortune, Miss. Ethel Flora
# 409        1         1                     Fortune, Miss. Alice Elizabeth
# 414        1         1                Fortune, Mrs. Mark (Mary McDougald)
# 199        1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 1239       1         1                                   Ward, Miss. Anna
# 198        1         1                 Cardeza, Mr. Thomas Drake Martinez
# 710        1         1                             Lesurer, Mr. Gustave J
# 1155       3         0                                 Storey, Mr. Thomas
#
#          sex   age  sibsp  parch    ticket      fare            cabin  \
# 610     male  49.0      0      0      LINE    1.0000              NaN
# 190     male   NaN      0      0    239853    1.0000              NaN
# 670     male   NaN      0      0    239855    1.0000              NaN
# 1247    male   NaN      0      0    239856    1.0000              NaN
# 935     male   NaN      0      0    239853    1.0000              NaN
# 936     male   NaN      0      0    112052    1.0000              NaN
# 612     male  19.0      0      0      LINE    1.0000              NaN
# 426     male   NaN      0      0    239854    1.0000              NaN
# 1200    male  25.0      0      0      LINE    1.0000              NaN
# 46      male  39.0      0      0    112050    1.0000              A36
# 427     male   NaN      0      0    112058    1.0000             B102
# 232     male   NaN      0      0    112051    1.0000              NaN
# 585     male  49.0      0      0    112058    1.0000      B52 B54 B56
# 288     male   NaN      0      0    239853    1.0000              NaN
# 515     male  40.0      0      0    112059    1.0000              B94
# 707     male  36.0      0      0      LINE    1.0000              NaN
# 997     male  38.0      0      0     19972    1.0000              NaN
# 900     male   9.0      0      1   C 17368    3.1708              NaN
# 119     male  20.0      0      0      2648    4.0125              NaN
# 202     male  33.0      0      0       695    5.0000      B51 B53 B55
# 885     male  61.0      0      0    345364    6.2375              NaN
# 1185    male   NaN      1      0      2621    6.4375              NaN
# 1186    male   NaN      0      0      2681    6.4375              NaN
# 703     male  34.5      0      0      2683    6.4375              NaN
# 560     male  43.0      0      0    C 7075    6.4500              NaN
# 1277    male  21.0      1      0   3101266    6.4958              NaN
# 602     male  34.0      0      0   3101264    6.4958              NaN
# 1276    male  18.0      1      0   3101267    6.4958              NaN
# 530   female  18.0      0      0    365226    6.7500              NaN
# 170     male  19.0      0      0    365222    6.7500              NaN
# ...      ...   ...    ...    ...       ...       ...              ...
# 1159    male  67.0      1      0  PC 17483  221.7792          C55 C57
# 1160  female  63.0      1      0  PC 17483  221.7792          C55 C57
# 387     male   NaN      0      0  PC 17483  221.7792              C95
# 122   female  29.0      0      0  PC 17483  221.7792              C97
# 68      male  47.0      1      0  PC 17757  227.5250          C62 C64
# 120   female  42.0      0      0  PC 17757  227.5250              NaN
# 69    female  18.0      1      0  PC 17757  227.5250          C62 C64
# 1018    male   NaN      0      0  PC 17757  227.5250              NaN
# 381   female  38.0      0      0  PC 17757  227.5250              C45
# 98      male  24.0      0      1  PC 17558  247.5208          B58 B60
# 349   female  27.0      1      1  PC 17558  247.5208          B58 B60
# 99    female  50.0      0      1  PC 17558  247.5208          B58 B60
# 1048  female  48.0      1      3  PC 17608  262.3750  B57 B59 B63 B66
# 1046  female  21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66
# 227   female  36.0      0      0  PC 17608  262.3750              B61
# 1045  female  18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66
# 144   female  45.0      0      0  PC 17608  262.3750              NaN
# 1044    male  13.0      2      2  PC 17608  262.3750  B57 B59 B63 B66
# 1047    male  61.0      1      3  PC 17608  262.3750  B57 B59 B63 B66
# 411   female  23.0      3      2     19950  263.0000      C23 C25 C27
# 412     male  19.0      3      2     19950  263.0000      C23 C25 C27
# 413     male  64.0      1      4     19950  263.0000      C23 C25 C27
# 410   female  28.0      3      2     19950  263.0000      C23 C25 C27
# 409   female  24.0      3      2     19950  263.0000      C23 C25 C27
# 414   female  60.0      1      4     19950  263.0000      C23 C25 C27
# 199   female  58.0      0      1  PC 17755  512.3292      B51 B53 B55
# 1239  female  35.0      0      0  PC 17755  512.3292              NaN
# 198     male  36.0      0      1  PC 17755  512.3292      B51 B53 B55
# 710     male  35.0      0      0  PC 17755  512.3292             B101
# 1155    male  60.5      0      0      3701       NaN              NaN
#
#      embarked boat   body                                       home.dest
# 610         S  NaN    NaN                                             NaN
# 190         S  NaN    NaN                                         Belfast
# 670         S  NaN    NaN                                         Belfast
# 1247        S  NaN    NaN                                         Belfast
# 935         S  NaN    NaN                                         Belfast
# 936         S  NaN    NaN                                         Belfast
# 612         S  NaN    NaN                                             NaN
# 426         S  NaN    NaN                                         Belfast
# 1200        S   15    NaN                                             NaN
# 46          S  NaN    NaN                                     Belfast, NI
# 427         S  NaN    NaN                                             NaN
# 232         S  NaN    NaN                    Liverpool, England / Belfast
# 585         S    C    NaN                                       Liverpool
# 288         S  NaN    NaN                                         Belfast
# 515         S  NaN  110.0                                             NaN
# 707         S  NaN    NaN                                             NaN
# 997         S  NaN    NaN                          Rotterdam, Netherlands
# 900         S   13    NaN                                             NaN
# 119         C  NaN    NaN                                           Syria
# 202         S  NaN    NaN                                    New York, NY
# 885         S  NaN    NaN                                             NaN
# 1185        C  NaN    NaN                                             NaN
# 1186        C  NaN    NaN                                             NaN
# 703         C  NaN  196.0                                             NaN
# 560         S  NaN    NaN                                             NaN
# 1277        S  NaN    NaN                                             NaN
# 602         S  NaN  143.0                                             NaN
# 1276        S  NaN  314.0                                             NaN
# 530         Q  NaN    NaN                                             NaN
# 170         Q  NaN    NaN                Co Cork, Ireland Charlestown, MA
# ...       ...  ...    ...                                             ...
# 1159        S  NaN   96.0                                    New York, NY
# 1160        S  NaN    NaN                                    New York, NY
# 387         S  NaN    NaN                                             NaN
# 122         S    8    NaN                                             NaN
# 68          C  NaN  124.0                                    New York, NY
# 120         C    4    NaN                                             NaN
# 69          C    4    NaN                                    New York, NY
# 1018        C  NaN    NaN                                             NaN
# 381         C    4    NaN                                    New York, NY
# 98          C  NaN    NaN                                    Montreal, PQ
# 349         C    6    NaN                                    Montreal, PQ
# 99          C    6    NaN                                    Montreal, PQ
# 1048        C    4    NaN                 Haverford, PA / Cooperstown, NY
# 1046        C    4    NaN                 Haverford, PA / Cooperstown, NY
# 227         C    4    NaN                                             NaN
# 1045        C    4    NaN                 Haverford, PA / Cooperstown, NY
# 144         C    4    NaN                                 Cooperstown, NY
# 1044        C    4    NaN                 Haverford, PA / Cooperstown, NY
# 1047        C  NaN    NaN                 Haverford, PA / Cooperstown, NY
# 411         S   10    NaN                                    Winnipeg, MB
# 412         S  NaN    NaN                                    Winnipeg, MB
# 413         S  NaN    NaN                                    Winnipeg, MB
# 410         S   10    NaN                                    Winnipeg, MB
# 409         S   10    NaN                                    Winnipeg, MB
# 414         S   10    NaN                                    Winnipeg, MB
# 199         C    3    NaN                    Germantown, Philadelphia, PA
# 1239        C    3    NaN                                             NaN
# 198         C    3    NaN  Austria-Hungary / Germantown, Philadelphia, PA
# 710         C    3    NaN                                             NaN
# 1155        S  NaN  261.0                                             NaN
#
# [1309 rows x 14 columns]

# %%
median_fare = titanic.fare.median()
median_fare
# Out:
# 14.4542

# %%
titanic["fare"].fillna(14.4542, inplace = True)

# %%
titanic["fare"].isna().sum()
# Out:
# 0

# %% [markdown]
# The blank fare has now been replaced by a median fare of 14.4542.
# The last step is to remove the 512.3292 outlier fares.

# %%
titanic.drop(titanic[titanic['fare'] > 500.0].index, inplace = True)

# %%
titanic.sort_values(by='fare', ascending=False)
# Out:
#       pclass  survived                                               name  \
# 411        1         1                         Fortune, Miss. Mabel Helen
# 414        1         1                Fortune, Mrs. Mark (Mary McDougald)
# 413        1         0                                  Fortune, Mr. Mark
# 412        1         0                     Fortune, Mr. Charles Alexander
# 410        1         1                         Fortune, Miss. Ethel Flora
# 409        1         1                     Fortune, Miss. Alice Elizabeth
# 227        1         1                        Chaudanson, Miss. Victorine
# 1048       1         1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 1044       1         1                        Ryerson, Master. John Borie
# 1047       1         0                         Ryerson, Mr. Arthur Larned
# 1046       1         1              Ryerson, Miss. Susan Parker "Suzette"
# 144        1         1                           Bowen, Miss. Grace Scott
# 1045       1         1                         Ryerson, Miss. Emily Borie
# 99         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 349        1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 98         1         0                           Baxter, Mr. Quigg Edmond
# 381        1         1                      Endres, Miss. Caroline Louise
# 1018       1         0                                Robbins, Mr. Victor
# 120        1         1                              Bidois, Miss. Rosalie
# 69         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 68         1         0                             Astor, Col. John Jacob
# 1160       1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 387        1         0                                 Farthing, Mr. John
# 1159       1         0                                 Straus, Mr. Isidor
# 122        1         1                                  Bird, Miss. Ellen
# 1274       1         0                          Widener, Mr. Harry Elkins
# 1273       1         0                         Widener, Mr. George Dunton
# 440        1         1                               Geiger, Miss. Amalie
# 643        1         0                                 Keeping, Mr. Edwin
# 1275       1         1       Widener, Mrs. George Dunton (Eleanor Elkins)
# ...      ...       ...                                                ...
# 530        3         0                       Hegarty, Miss. Hanora "Nora"
# 170        3         0                                Burke, Mr. Jeremiah
# 1277       3         0                            Wiklund, Mr. Karl Johan
# 1276       3         0                          Wiklund, Mr. Jakob Alfred
# 602        3         0                         Johanson, Mr. Jakob Alfred
# 560        3         0                   Holm, Mr. John Fredrik Alexander
# 703        3         0                         Lemberopolous, Mr. Peter L
# 1185       3         0                              Thomas, Mr. Charles P
# 1186       3         0                                   Thomas, Mr. John
# 885        3         0                          Nysveen, Mr. Johan Hansen
# 202        1         0                           Carlsson, Mr. Frans Olof
# 119        3         0                                Betros, Mr. Tannous
# 900        3         1                          Olsen, Master. Artur Karl
# 1247       2         0                         Watson, Mr. Ennis Hastings
# 610        3         0                                Johnson, Mr. Alfred
# 707        3         0                                Leonard, Mr. Lionel
# 612        3         0                    Johnson, Mr. William Cahoone Jr
# 427        1         0                                   Fry, Mr. Richard
# 670        2         0                               Knight, Mr. Robert J
# 190        2         0                              Campbell, Mr. William
# 935        2         0                        Parkes, Mr. Francis "Frank"
# 426        2         0                   Frost, Mr. Anthony Wood "Archie"
# 936        1         0                      Parr, Mr. William Henry Marsh
# 997        1         0                    Reuchlin, Jonkheer. John George
# 288        2         0                     Cunningham, Mr. Alfred Fleming
# 515        1         0                              Harrison, Mr. William
# 232        1         0              Chisholm, Mr. Roderick Robert Crispin
# 1200       3         1                       Tornquist, Mr. William Henry
# 46         1         0                             Andrews, Mr. Thomas Jr
# 585        1         1                            Ismay, Mr. Joseph Bruce
#
#          sex   age  sibsp  parch    ticket      fare            cabin  \
# 411   female  23.0      3      2     19950  263.0000      C23 C25 C27
# 414   female  60.0      1      4     19950  263.0000      C23 C25 C27
# 413     male  64.0      1      4     19950  263.0000      C23 C25 C27
# 412     male  19.0      3      2     19950  263.0000      C23 C25 C27
# 410   female  28.0      3      2     19950  263.0000      C23 C25 C27
# 409   female  24.0      3      2     19950  263.0000      C23 C25 C27
# 227   female  36.0      0      0  PC 17608  262.3750              B61
# 1048  female  48.0      1      3  PC 17608  262.3750  B57 B59 B63 B66
# 1044    male  13.0      2      2  PC 17608  262.3750  B57 B59 B63 B66
# 1047    male  61.0      1      3  PC 17608  262.3750  B57 B59 B63 B66
# 1046  female  21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66
# 144   female  45.0      0      0  PC 17608  262.3750              NaN
# 1045  female  18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66
# 99    female  50.0      0      1  PC 17558  247.5208          B58 B60
# 349   female  27.0      1      1  PC 17558  247.5208          B58 B60
# 98      male  24.0      0      1  PC 17558  247.5208          B58 B60
# 381   female  38.0      0      0  PC 17757  227.5250              C45
# 1018    male   NaN      0      0  PC 17757  227.5250              NaN
# 120   female  42.0      0      0  PC 17757  227.5250              NaN
# 69    female  18.0      1      0  PC 17757  227.5250          C62 C64
# 68      male  47.0      1      0  PC 17757  227.5250          C62 C64
# 1160  female  63.0      1      0  PC 17483  221.7792          C55 C57
# 387     male   NaN      0      0  PC 17483  221.7792              C95
# 1159    male  67.0      1      0  PC 17483  221.7792          C55 C57
# 122   female  29.0      0      0  PC 17483  221.7792              C97
# 1274    male  27.0      0      2    113503  211.5000              C82
# 1273    male  50.0      1      1    113503  211.5000              C80
# 440   female  35.0      0      0    113503  211.5000             C130
# 643     male  32.5      0      0    113503  211.5000             C132
# 1275  female  50.0      1      1    113503  211.5000              C80
# ...      ...   ...    ...    ...       ...       ...              ...
# 530   female  18.0      0      0    365226    6.7500              NaN
# 170     male  19.0      0      0    365222    6.7500              NaN
# 1277    male  21.0      1      0   3101266    6.4958              NaN
# 1276    male  18.0      1      0   3101267    6.4958              NaN
# 602     male  34.0      0      0   3101264    6.4958              NaN
# 560     male  43.0      0      0    C 7075    6.4500              NaN
# 703     male  34.5      0      0      2683    6.4375              NaN
# 1185    male   NaN      1      0      2621    6.4375              NaN
# 1186    male   NaN      0      0      2681    6.4375              NaN
# 885     male  61.0      0      0    345364    6.2375              NaN
# 202     male  33.0      0      0       695    5.0000      B51 B53 B55
# 119     male  20.0      0      0      2648    4.0125              NaN
# 900     male   9.0      0      1   C 17368    3.1708              NaN
# 1247    male   NaN      0      0    239856    1.0000              NaN
# 610     male  49.0      0      0      LINE    1.0000              NaN
# 707     male  36.0      0      0      LINE    1.0000              NaN
# 612     male  19.0      0      0      LINE    1.0000              NaN
# 427     male   NaN      0      0    112058    1.0000             B102
# 670     male   NaN      0      0    239855    1.0000              NaN
# 190     male   NaN      0      0    239853    1.0000              NaN
# 935     male   NaN      0      0    239853    1.0000              NaN
# 426     male   NaN      0      0    239854    1.0000              NaN
# 936     male   NaN      0      0    112052    1.0000              NaN
# 997     male  38.0      0      0     19972    1.0000              NaN
# 288     male   NaN      0      0    239853    1.0000              NaN
# 515     male  40.0      0      0    112059    1.0000              B94
# 232     male   NaN      0      0    112051    1.0000              NaN
# 1200    male  25.0      0      0      LINE    1.0000              NaN
# 46      male  39.0      0      0    112050    1.0000              A36
# 585     male  49.0      0      0    112058    1.0000      B52 B54 B56
#
#      embarked boat   body                         home.dest
# 411         S   10    NaN                      Winnipeg, MB
# 414         S   10    NaN                      Winnipeg, MB
# 413         S  NaN    NaN                      Winnipeg, MB
# 412         S  NaN    NaN                      Winnipeg, MB
# 410         S   10    NaN                      Winnipeg, MB
# 409         S   10    NaN                      Winnipeg, MB
# 227         C    4    NaN                               NaN
# 1048        C    4    NaN   Haverford, PA / Cooperstown, NY
# 1044        C    4    NaN   Haverford, PA / Cooperstown, NY
# 1047        C  NaN    NaN   Haverford, PA / Cooperstown, NY
# 1046        C    4    NaN   Haverford, PA / Cooperstown, NY
# 144         C    4    NaN                   Cooperstown, NY
# 1045        C    4    NaN   Haverford, PA / Cooperstown, NY
# 99          C    6    NaN                      Montreal, PQ
# 349         C    6    NaN                      Montreal, PQ
# 98          C  NaN    NaN                      Montreal, PQ
# 381         C    4    NaN                      New York, NY
# 1018        C  NaN    NaN                               NaN
# 120         C    4    NaN                               NaN
# 69          C    4    NaN                      New York, NY
# 68          C  NaN  124.0                      New York, NY
# 1160        S  NaN    NaN                      New York, NY
# 387         S  NaN    NaN                               NaN
# 1159        S  NaN   96.0                      New York, NY
# 122         S    8    NaN                               NaN
# 1274        C  NaN    NaN                   Elkins Park, PA
# 1273        C  NaN    NaN                   Elkins Park, PA
# 440         C    4    NaN                               NaN
# 643         C  NaN   45.0                               NaN
# 1275        C    4    NaN                   Elkins Park, PA
# ...       ...  ...    ...                               ...
# 530         Q  NaN    NaN                               NaN
# 170         Q  NaN    NaN  Co Cork, Ireland Charlestown, MA
# 1277        S  NaN    NaN                               NaN
# 1276        S  NaN  314.0                               NaN
# 602         S  NaN  143.0                               NaN
# 560         S  NaN    NaN                               NaN
# 703         C  NaN  196.0                               NaN
# 1185        C  NaN    NaN                               NaN
# 1186        C  NaN    NaN                               NaN
# 885         S  NaN    NaN                               NaN
# 202         S  NaN    NaN                      New York, NY
# 119         C  NaN    NaN                             Syria
# 900         S   13    NaN                               NaN
# 1247        S  NaN    NaN                           Belfast
# 610         S  NaN    NaN                               NaN
# 707         S  NaN    NaN                               NaN
# 612         S  NaN    NaN                               NaN
# 427         S  NaN    NaN                               NaN
# 670         S  NaN    NaN                           Belfast
# 190         S  NaN    NaN                           Belfast
# 935         S  NaN    NaN                           Belfast
# 426         S  NaN    NaN                           Belfast
# 936         S  NaN    NaN                           Belfast
# 997         S  NaN    NaN            Rotterdam, Netherlands
# 288         S  NaN    NaN                           Belfast
# 515         S  NaN  110.0                               NaN
# 232         S  NaN    NaN      Liverpool, England / Belfast
# 1200        S   15    NaN                               NaN
# 46          S  NaN    NaN                       Belfast, NI
# 585         S    C    NaN                         Liverpool
#
# [1305 rows x 14 columns]

# %% [markdown]
# Now the largest fare listed is 263.

# %% [markdown]
# The next part of the analysis will provide the descriptive statistics of the data.

# %%
mean_pclass = titanic.pclass.mean()
#mean_survived = titanic.survived.mean()
#mean_sex = titanic.sex.mean()
mean_age = titanic.age.mean()
mean_fare = titanic.fare.mean()
print("The mean pclass is: ", mean_pclass)
#print("The mean survived is: ", mean_survived)
#print("The mean sex is: ", mean_sex)
print("The mean age is: ", mean_age)
print("The mean fare is: ", mean_fare)

#The survived and sex variables do not have a mean because they are boolean values
# Out:
# The mean pclass is:  2.2988505747126435
# The mean age is:  29.838451727447218
# The mean fare is:  31.825765747126518

# %%
median_pclass = titanic.pclass.median()
#median_survived = titanic.survived.median()
#median_sex = titanic.sex.median()
median_age = titanic.age.median()
median_fare = titanic.fare.median()
print("The median pclass is: ", median_pclass)
#print("The median survived is: ", median_survived)
#print("The median sex is: ", median_sex)
print("The median age is: ", median_age)
print("The median fare is: ", median_fare)

#The survived and sex variables do not have a median because they are boolean values
# Out:
# The median pclass is:  3.0
# The median age is:  28.0
# The median fare is:  14.4542

# %%
mode_pclass = titanic.pclass.mode()
#mode_survived = titanic.survived.mode()
#mode_sex = titanic.sex.mode()
mode_age = titanic.age.mode()
mode_fare = titanic.fare.mode()
print("The mode of pclass is: ", mode_pclass)
#print("The mode of survived is: ", mode_survived)
#print("The mode of sex is: ", mode_sex)
print("The mode of age is: ", mode_age)
print("The mode of fare is: ", mode_fare)

#The survived and sex variables do not have a mode because they are boolean values
# Out:
# The mode of pclass is:  0    3
# dtype: int64
# The mode of age is:  0    24.0
# dtype: float64
# The mode of fare is:  0    8.05
# dtype: float64

# %%
var_pclass = titanic.pclass.var()
#var_survived = titanic.survived.var()
#var_sex = titanic.sex.var()
var_age = titanic.age.var()
var_fare = titanic.fare.var()
print("The variance/spread of pclass is: ", var_pclass)
#print("The variance/spread of survived is: ", var_survived)
#print("The variance/spread of sex is: ", var_sex)
print("The variance/spread of age is: ", var_age)
print("The variance/spread of fare is: ", var_fare)

#The survived and sex variables do not have a variance/spread because they are boolean values
# Out:
# The variance/spread of pclass is:  0.6989634017347074
# The variance/spread of age is:  207.6995796312988
# The variance/spread of fare is:  1978.47256677096

# %%
std_pclass = titanic.pclass.std()
#std_survived = titanic.survived.std()
#std_sex = titanic.sex.std()
std_age = titanic.age.std()
std_fare = titanic.fare.std()
print("The standard deviation of pclass is: ", std_pclass)
#print("The standard deviation of survived is: ", std_survived)
#print("The standard deviation of sex is: ", std_sex)
print("The standard deviation of age is: ", std_age)
print("The standard deviation of fare is: ", std_fare)

#The survived and sex variables do not have a standard deviation because they are boolean values
# Out:
# The standard deviation of pclass is:  0.8360403110704097
# The standard deviation of age is:  14.411786136051937
# The standard deviation of fare is:  44.48002435668128

# %%
#The tails of the distributions are calculated with the kurtosis function
titanic.kurtosis()
# Out:
# pclass      -1.301563
# survived    -1.757983
# age          0.151390
# sibsp       19.982678
# parch       21.524551
# fare        11.144360
# body        -1.254052
# dtype: float64

# %% [markdown]
# A kurtosis < 3 is called platykurtic and means that the tails are shorter and thinner than those of a normal distirbution. A kurtosis > 3 is called leptykurtic and means that the tails are longer and fatter than those of a normal distribution.
#
# Our data has pclass, survived, age, and body as having shorter and thinner tails than a normal distribution, while sibsp, parch, and fare have tails that are longer and fatter than a normal distribution.

# %%
#Here is a nice summary table
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1305.000000  1305.000000  1042.000000  1305.000000  1305.000000
# mean      2.298851     0.380077    29.838452     0.500383     0.384674
# std       0.836040     0.485591    14.411786     1.042888     0.866421
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1305.000000  121.000000
# mean     31.825766  160.809917
# std      44.480024   97.696922
# min       1.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.000000  256.000000
# max     263.000000  328.000000

# %% [markdown]
# The summary table above is also a good sanity check that our data correction processes did indeed work.
# The original data contained 1309 rows.  Once we got rid of the four 512.3292 fares, we dropped down to 1305.
# We can also see that our lowest fare is now 1.0 and the largest is 263.

# %%
poor = titanic[titanic.fare < 50.0]
others = titanic[titanic.fare >=50.0]

#To construct my PMF, I am going to make two groups of people 
#I separated them based on purchase fare.  It looked like most people in 3rd class paid less than 50 Pounds for their ticket.  I categorized these people as poor.

# %%
#To make sure I captured everyone
print(len(poor))
print(len(others))
print(len(titanic))
# Out:
# 1067
# 238
# 1305

# %%
#Here is where we create the pmfs
pmf_poor = thinkstats2.Pmf(poor.fare, label="poor")
pmf_others = thinkstats2.Pmf(others.fare, label="others")

# %%
#Here are the PMF plots of poor and others.
width=0.45
axis = [0, 265, 0, 0.1]
thinkplot.PrePlot(2, cols=2)
thinkplot.Hist(pmf_poor, align="right", width=width)
thinkplot.Hist(pmf_others, align="left", width=width)
thinkplot.Config(xlabel="Passenger Fare", ylabel="Probability", axis=[0, 265, 0, 0.1])
thinkplot.PrePlot(2)
thinkplot.SubPlot(2)
thinkplot.Pmfs([pmf_poor, pmf_others])
thinkplot.Show(xlabel="Passenger Fare", axis=[0, 265, 0, 0.1])

# %% [markdown]
# These plots indicate that there is a greater probability that if a passenger purchased a ticket for less than 50 Pounds, they were considered "poor".
#
# A PMF is not the best way to visualize this data.  As the text states on page 39, "PMFs work well if the number of values is small.  But as the number of values increases, the probability associated with each value gets smaller and the effect of random noise increases."  Evidence of this is the small scale on the probability axis.  This is why my plots look like the noisy plot on page 40.

# %%
#Here is the CDF of passenger fare
cdf_fare = thinkstats2.Cdf(titanic.fare, label="fare")
thinkplot.Cdf(cdf_fare)
thinkplot.Show(xlabel="Passenger Fare", ylabel="CDF")

# %% [markdown]
# It looks like close to 80% of the passengers paid less than 50 Pounds for their fare.  This means that most of the people on the Titanic were "poor".  At least as far as the under 50 Pounds threshold I established earlier.  So if we are looking at whether most of the people that died were poor, we can immediately establish that to be true since most of the people were indeed poor, regardless of whether they died or not.  Therefore, based on our under 50 Pounds limit, most of the people that died on the Titanic were poor.

# %%
#From the CDF plot, it looks like passenger fare follows the Pareto Distribution.
#Based on the plot in our text on p. 59, I chose my alpha to be 2.
#Here is the model.
xmin = 0.5

thinkplot.PrePlot(3)
for alpha in [2.0]:
    xs, ps = thinkstats2.RenderParetoCdf(xmin, alpha, 0, 10, n=100) 
    thinkplot.Plot(xs, ps, label=r'$\alpha=%g$' % alpha)
    
thinkplot.Config(title='Pareto CDF', xlabel='x',
                 ylabel='CDF', loc='lower right')

# %%
#Now if we include the model and the data, we obtain:
xmin = 0.5

thinkplot.PrePlot(3)
for alpha in [2.0]:
    xs, ps = thinkstats2.RenderParetoCdf(xmin, alpha, 0, 500.0, n=100) 
    thinkplot.Plot(xs, ps, label='model')
cdf_fare = thinkstats2.Cdf(titanic.fare, label="data")
thinkplot.Cdf(cdf_fare)
thinkplot.Show(xlabel="Passenger Fare", ylabel="CDF")

# %% [markdown]
# Not as good of a fit as I initially supposed.  This is due to the scaling of the x-axis.

# %%
log_fare = np.log10(titanic.fare)
cdf_fare = thinkstats2.Cdf(titanic.fare, label="data")
cdf_log = thinkstats2.Cdf(log_fare, label="data")

# pareto plot
xs, ys = thinkstats2.RenderParetoCdf(xmin, alpha, 0, 500, n=100)
thinkplot.Plot(np.log10(xs), 1-ys, label='model', color='0.8')

thinkplot.Cdf(cdf_log, complement=True) 
thinkplot.Config(xlabel='log10 population',
                 ylabel='CCDF',
                 yscale='log', loc='lower left')

# %% [markdown]
# This is even more evident when you overlay the lognormal distribution.  Therefore, a Pareto model is not the best choice for representing passenger fares.  An exponential distribution would be the next distribution I would try.

# %%
#Scatter plot for fare vs survived
titanic.plot.scatter(x='fare', y='survived', c='DarkBlue')

# %% [markdown]
# I realize that this isn't the most informative scatter plot, but there is a particular reason I chose these two variables, and there are some things we can learn from this plot.
# I chose these two variables because my hypothesis states that most of the people that died on the Titanic were poor.  The scatter plot does indeed indicate this trend in that there are more data points below 50 for survived=0.
# To get a better idea of how these two variables could be related, we need to look at the correlation and covariance.

# %%
def Cov(xs, ys, meanx=None, meany=None):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    if meanx is None:
        meanx = np.mean(xs)
    if meany is None:
        meany = np.mean(ys)

    cov = np.dot(xs-meanx, ys-meany) / len(xs)
    return cov

# %%
cleaned = titanic.dropna(subset=['fare', 'survived'])
fares, survives = cleaned.fare, cleaned.survived
print("The covariance between fare and survived is: ", Cov(fares, survives))
# Out:
# The covariance between fare and survived is:  5.2472760072224425

# %% [markdown]
# Covariance is useful for some calculations, but it doesn't mean much by itself. The coefficient of correlation is a standardized version of covariance that is easier to interpret.

# %%
def Corr(xs, ys):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    meanx, varx = thinkstats2.MeanVar(xs)
    meany, vary = thinkstats2.MeanVar(ys)

    corr = Cov(xs, ys, meanx, meany) / np.sqrt(varx * vary)
    return corr

# %%
print("The Pearson's correlation between fare and survived is: ", Corr(fares, survives))
# Out:
# The Pearson's correlation between fare and survived is:  0.24312564179354665

# %% [markdown]
# The correlation is positive which means that when one variable (fare) is high, the other variable (survived) tends to be high.  However, given that our Pearson's correlation is only 0.243, the relationship is quite weak.  In other words, the correlation is low.

# %% [markdown]
# One final thing we can conclude from this scatter plot is that the relationship between fare and survived is not linear.  And this is exactly what we would expect from a binomial variable like we have for survived.

# %%
#Scatter plot for fare vs age
titanic.plot.scatter(x='fare', y='age', c='DarkBlue')

# %% [markdown]
# This scatter plot shows us that there appears to be slight correlation between age and fare.  While there isn't a definitive connection, one can generally say that the older a person was, the more they paid for their fare.  This is particularly evident with the large grouping of data between 0-50 on fare and 0-10 on age.
# We can also see that this is a non-linear relationship.
# Let's now look at covariance and Pearson's correlation to get a more accurate representation.

# %%
#Scatter plot for passenger class vs survival
titanic.plot.scatter(x="age", y="survived", c="DarkBlue")

# %%
cleaned2 = titanic.dropna(subset=['fare', 'age'])
fares, ages = cleaned2.fare, cleaned2.age
print("The covariance between fare and age is: ", Cov(fares, ages))
# Out:
# The covariance between fare and age is:  122.63464836577623

# %% [markdown]
# Again, covariance is useful for some calculations, but it doesn't mean much by itself. The coefficient of correlation is a standardized version of covariance that is easier to interpret.

# %%
print("The Pearson's correlation between fare and age is: ", Corr(fares, ages))
# Out:
# The Pearson's correlation between fare and age is:  0.17987304789244452

# %% [markdown]
# The correlation is positive which means that when one variable (fare) is high, the other variable (age) tends to be high.  However, given that our Pearson's correlation is only 0.180, the relationship is quite weak.  In other words, the correlation is low.

# %% [markdown]
# In summary, because both scatter plots provided such low correlation values, we can conclude that each variable does not cause the other variable.  In other words, low correlation indicates low causation.

# %% [markdown]
# To test my hypothesis that passenger fare is related to passenger age, I will perform a chi-square test.
# One key assumption for the chi-square test is that the value of expected cells should be greater than 5 for at least 20% of the cells in order for the chi-square value to be trusted.

# %%
import pandas
from scipy.stats import chi2_contingency

def chisq_of_df_cols(df, c1, c2):
    groupsizes = df.groupby([c1, c2]).size()
    ctsum = groupsizes.unstack(c1)
    # fillna(0) is necessary to remove any NAs which will cause exceptions
    return(chi2_contingency(ctsum.fillna(0)))

test_df = pandas.DataFrame(titanic, columns=['age', 'fare'])
chisq_of_df_cols(test_df, 'age', 'fare')
# Out:
# (26034.045082311422,
#  3.2668448616278446e-10,
#  24638,
#  array([[0.00383877, 0.00383877, 0.00383877, ..., 0.00383877, 0.00383877,
#          0.00383877],
#         [0.00287908, 0.00287908, 0.00287908, ..., 0.00287908, 0.00287908,
#          0.00287908],
#         [0.00191939, 0.00191939, 0.00191939, ..., 0.00191939, 0.00191939,
#          0.00191939],
#         ...,
#         [0.00095969, 0.00095969, 0.00095969, ..., 0.00095969, 0.00095969,
#          0.00095969],
#         [0.00095969, 0.00095969, 0.00095969, ..., 0.00095969, 0.00095969,
#          0.00095969],
#         [0.00095969, 0.00095969, 0.00095969, ..., 0.00095969, 0.00095969,
#          0.00095969]]))

# %% [markdown]
# The first value (26034) is the chi-square value, followed by the p-value (3.27e-10), then comes the degrees of freedom (24638), and lastly it outputs the expected frequencies as an array. Since all of the expected frequencies are less than 5, the chi-square test results cannot be trusted. We can reject the null hypothesis as the p-value is less than 0.05. Thus, the results indicate that there is not a relationship between passenger age and passenger fare.
#
# This result corresponds to the conclusion we stated based on the Pearson's Correlation value of 0.180 obtained earlier.
#
# So the slight correlation I thought I observed in the scatter plot is not really there.

# %% [markdown]
# Finally, we will construct a logistic regression model to see if I would have survived the Titanic.
#
# I am going to use the following variables: survived, sex, age, and fare.
# I am going to have to convert the sex responses to 1s for males and 0s for females.

# %%
titanic['sex'].replace(["female", "male"],[0, 1],inplace=True)

# %%
titanic.sort_values(by='sex')
# Out:
#       pclass  survived                                               name  \
# 654        3         0          Khalil, Mrs. Betros (Zahie "Maria" Elias)
# 1019       1         1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 1017       3         0                         Risien, Mrs. Samuel (Emma)
# 461        3         1     Goldsmith, Mrs. Frank John (Emily Alice Brown)
# 1015       3         1                    Riordan, Miss. Johanna "Hannah"
# 466        3         0                        Goodwin, Miss. Jessie Allis
# 467        3         0                         Goodwin, Miss. Lillian Amy
# 456        1         1       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 1012       3         0       Riihivouri, Miss. Susanna Juhantytar "Sanni"
# 470        3         0            Goodwin, Mrs. Frederick (Augusta Tyler)
# 1010       2         1              Richards, Mrs. Sidney (Emily Hocking)
# 472        1         1                       Graham, Miss. Margaret Edith
# 474        1         1      Graham, Mrs. William Thompson (Edith Junkins)
# 1006       3         0               Rice, Mrs. William (Margaret Norton)
# 478        1         1       Greenfield, Mrs. Leo David (Blanche Strouse)
# 1011       2         1                               Ridsdale, Miss. Lucy
# 486        3         0                                Haas, Miss. Aloisia
# 1021       3         0     Robins, Mrs. Alexander A (Grace Charity Laury)
# 452        3         1                   Gilnagh, Miss. Katherine "Katie"
# 425        1         1  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 428        2         0                          Funk, Miss. Annie Clemmer
# 1040       2         1                                  Rugg, Miss. Emily
# 430        1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 1037       1         1     Rothschild, Mrs. Martin (Elizabeth L. Barrett)
# 1035       1         1  Rothes, the Countess. of (Lucy Noel Martha Dye...
# 454        3         1                           Glynn, Miss. Mary Agatha
# 436        2         1                               Garside, Miss. Ethel
# 440        1         1                               Geiger, Miss. Amalie
# 1031       1         1                      Rosenbaum, Miss. Edith Louise
# 442        1         1                     Gibson, Miss. Dorothy Winifred
# ...      ...       ...                                                ...
# 499        3         0                        Hansen, Mr. Henry Damsgaard
# 501        2         0                             Harbeck, Mr. William H
# 502        1         1                        Harder, Mr. George Achilles
# 505        3         0                 Harmer, Mr. Abraham (David Lishin)
# 507        1         1                          Harper, Mr. Henry Sleeper
# 509        2         0                                  Harper, Rev. John
# 510        1         0                          Harrington, Mr. Charles H
# 511        2         1                                 Harris, Mr. George
# 512        1         0                        Harris, Mr. Henry Birkhardt
# 513        2         0                                 Harris, Mr. Walter
# 515        1         0                              Harrison, Mr. William
# 517        2         0                                 Hart, Mr. Benjamin
# 518        3         0                                    Hart, Mr. Henry
# 556        2         0                            Hodges, Mr. Henry Price
# 520        1         1                                 Hassab, Mr. Hammad
# 522        1         1                        Hawksford, Mr. Walter James
# 524        1         0                         Hays, Mr. Charles Melville
# 526        1         0                              Head, Mr. Christopher
# 528        3         1                            Hedman, Mr. Oskar Arvid
# 529        3         1                                      Hee, Mr. Ling
# 534        3         0                             Hendekovic, Mr. Ignjac
# 539        2         0                                 Herman, Mr. Samuel
# 542        2         0                          Hickman, Mr. Leonard Mark
# 543        2         0                                 Hickman, Mr. Lewis
# 544        2         0                        Hickman, Mr. Stanley George
# 545        1         0                        Hilliard, Mr. Herbert Henry
# 547        1         0                        Hipkins, Mr. William Edward
# 553        2         0                        Hocking, Mr. Richard George
# 521        3         0                           Hassan, Mr. Houssein G N
# 1308       3         0                                 Zimmerman, Mr. Leo
#
#       sex   age  sibsp  parch        ticket      fare    cabin embarked boat  \
# 654     0   NaN      1      0          2660   14.4542      NaN        C  NaN
# 1019    0  43.0      0      1         24160  211.3375       B3        S    2
# 1017    0   NaN      0      0        364498   14.5000      NaN        S  NaN
# 461     0  31.0      1      1        363291   20.5250      NaN        S  C D
# 1015    0   NaN      0      0        334915    7.7208      NaN        Q   13
# 466     0  10.0      5      2       CA 2144   46.9000      NaN        S  NaN
# 467     0  16.0      5      2       CA 2144   46.9000      NaN        S  NaN
# 456     0   NaN      1      0         17453   89.1042      C92        C    5
# 1012    0  22.0      0      0       3101295   39.6875      NaN        S  NaN
# 470     0  43.0      1      6       CA 2144   46.9000      NaN        S  NaN
# 1010    0  24.0      2      3         29106   18.7500      NaN        S    4
# 472     0  19.0      0      0        112053   30.0000      B42        S    3
# 474     0  58.0      0      1      PC 17582  153.4625     C125        S    3
# 1006    0  39.0      0      5        382652   29.1250      NaN        Q  NaN
# 478     0  45.0      0      1      PC 17759   63.3583  D10 D12        C    7
# 1011    0  50.0      0      0   W./C. 14258   10.5000      NaN        S   13
# 486     0  24.0      0      0        349236    8.8500      NaN        S  NaN
# 1021    0  47.0      1      0     A/5. 3337   14.5000      NaN        S  NaN
# 452     0  16.0      0      0         35851    7.7333      NaN        Q   16
# 425     0  48.0      1      1         13567   79.2000      B41        C    5
# 428     0  38.0      0      0        237671   13.0000      NaN        S  NaN
# 1040    0  21.0      0      0    C.A. 31026   10.5000      NaN        S   12
# 430     0  35.0      1      0        113803   53.1000     C123        S    D
# 1037    0  54.0      1      0      PC 17603   59.4000      NaN        C    6
# 1035    0  33.0      0      0        110152   86.5000      B77        S    8
# 454     0   NaN      0      0        335677    7.7500      NaN        Q   13
# 436     0  34.0      0      0        243880   13.0000      NaN        S   12
# 440     0  35.0      0      0        113503  211.5000     C130        C    4
# 1031    0  33.0      0      0      PC 17613   27.7208      A11        C   11
# 442     0  22.0      0      1        112378   59.4000      NaN        C    7
# ...   ...   ...    ...    ...           ...       ...      ...      ...  ...
# 499     1  21.0      0      0        350029    7.8542      NaN        S  NaN
# 501     1  44.0      0      0        248746   13.0000      NaN        S  NaN
# 502     1  25.0      1      0         11765   55.4417      E50        C    5
# 505     1  25.0      0      0        374887    7.2500      NaN        S    B
# 507     1  48.0      1      0      PC 17572   76.7292      D33        C    3
# 509     1  28.0      0      1        248727   33.0000      NaN        S  NaN
# 510     1   NaN      0      0        113796   42.4000      NaN        S  NaN
# 511     1  62.0      0      0   S.W./PP 752   10.5000      NaN        S   15
# 512     1  45.0      1      0         36973   83.4750      C83        S  NaN
# 513     1  30.0      0      0     W/C 14208   10.5000      NaN        S  NaN
# 515     1  40.0      0      0        112059    1.0000      B94        S  NaN
# 517     1  43.0      1      1  F.C.C. 13529   26.2500      NaN        S  NaN
# 518     1   NaN      0      0        394140    6.8583      NaN        Q  NaN
# 556     1  50.0      0      0        250643   13.0000      NaN        S  NaN
# 520     1  27.0      0      0      PC 17572   76.7292      D49        C    3
# 522     1   NaN      0      0         16988   30.0000      D45        S    3
# 524     1  55.0      1      1         12749   93.5000      B69        S  NaN
# 526     1  42.0      0      0        113038   42.5000      B11        S  NaN
# 528     1  27.0      0      0        347089    6.9750      NaN        S   15
# 529     1   NaN      0      0          1601   56.4958      NaN        S    C
# 534     1  28.0      0      0        349243    7.8958      NaN        S  NaN
# 539     1  49.0      1      2        220845   65.0000      NaN        S  NaN
# 542     1  24.0      2      0  S.O.C. 14879   73.5000      NaN        S  NaN
# 543     1  32.0      2      0  S.O.C. 14879   73.5000      NaN        S  NaN
# 544     1  21.0      2      0  S.O.C. 14879   73.5000      NaN        S  NaN
# 545     1   NaN      0      0         17463   51.8625      E46        S  NaN
# 547     1  55.0      0      0           680   50.0000      C39        S  NaN
# 553     1  23.0      2      1         29104   11.5000      NaN        S  NaN
# 521     1  11.0      0      0          2699   18.7875      NaN        C  NaN
# 1308    1  29.0      0      0        315082    7.8750      NaN        S  NaN
#
#        body                                          home.dest
# 654     NaN                                                NaN
# 1019    NaN                                       St Louis, MO
# 1017    NaN                                                NaN
# 461     NaN                  Strood, Kent, England Detroit, MI
# 1015    NaN                                                NaN
# 466     NaN               Wiltshire, England Niagara Falls, NY
# 467     NaN               Wiltshire, England Niagara Falls, NY
# 456     NaN                       Paris, France / New York, NY
# 1012    NaN                                                NaN
# 470     NaN               Wiltshire, England Niagara Falls, NY
# 1010    NaN                               Cornwall / Akron, OH
# 472     NaN                                      Greenwich, CT
# 474     NaN                                      Greenwich, CT
# 1006  327.0                                                NaN
# 478     NaN                                       New York, NY
# 1011    NaN  London, England / Marietta, Ohio and Milwaukee...
# 486     NaN                                                NaN
# 1021    7.0                                                NaN
# 452     NaN                  Co Longford, Ireland New York, NY
# 425     NaN                                Zurich, Switzerland
# 428     NaN                      Janjgir, India / Pennsylvania
# 1040    NaN                          Guernsey / Wilmington, DE
# 430     NaN                                       Scituate, MA
# 1037    NaN                                       New York, NY
# 1035    NaN                              London  Vancouver, BC
# 454     NaN                   Co Clare, Ireland Washington, DC
# 436     NaN                                       Brooklyn, NY
# 440     NaN                                                NaN
# 1031    NaN                                      Paris, France
# 442     NaN                                       New York, NY
# ...     ...                                                ...
# 499    69.0                                                NaN
# 501    35.0                           Seattle, WA / Toledo, OH
# 502     NaN                                       Brooklyn, NY
# 505     NaN                                                NaN
# 507     NaN                                       New York, NY
# 509     NaN                     Denmark Hill, Surrey / Chicago
# 510     NaN                                                NaN
# 511     NaN                                             London
# 512     NaN                                       New York, NY
# 513     NaN                               Walthamstow, England
# 515   110.0                                                NaN
# 517     NaN                       Ilford, Essex / Winnipeg, MB
# 518     NaN                                                NaN
# 556   149.0                                        Southampton
# 520     NaN                                                NaN
# 522     NaN                                   Kingston, Surrey
# 524   307.0                                       Montreal, PQ
# 526     NaN                                 London / Middlesex
# 528     NaN                                                NaN
# 529     NaN                                                NaN
# 534   306.0                                                NaN
# 539     NaN                       Somerset / Bernardsville, NJ
# 542     NaN               West Hampstead, London / Neepawa, MB
# 543   256.0               West Hampstead, London / Neepawa, MB
# 544     NaN               West Hampstead, London / Neepawa, MB
# 545     NaN                                       Brighton, MA
# 547     NaN                                London / Birmingham
# 553     NaN                               Cornwall / Akron, OH
# 521     NaN                                                NaN
# 1308    NaN                                                NaN
#
# [1305 rows x 14 columns]

# %%
titanic.sort_values(by='sex', ascending=False)
# Out:
#      pclass  survived                                               name  sex  \
# 0         3         0                                Abbing, Mr. Anthony    1
# 726       2         0                                  Lingane, Mr. John    1
# 777       3         1                       McCormack, Mr. Thomas Joseph    1
# 780       3         1                                 McCoy, Mr. Bernard    1
# 781       2         0                          McCrae, Mr. Arthur Gordon    1
# 782       2         0                          McCrie, Mr. James Matthew    1
# 784       3         0                                McEvoy, Mr. Michael    1
# 785       1         1                          McGough, Mr. James Robert    1
# 789       2         0                            McKane, Mr. Peter David    1
# 790       3         0                                McMahon, Mr. Martin    1
# 791       3         0                                  McNamee, Mr. Neal    1
# 798       2         1                          Mellors, Mr. William John    1
# 799       3         0                                   Meo, Mr. Alfonzo    1
# 800       3         0                                Mernagh, Mr. Robert    1
# 801       2         0                                  Meyer, Mr. August    1
# 802       1         0                            Meyer, Mr. Edgar Joseph    1
# 804       3         1                           Midtsjo, Mr. Karl Albert    1
# 805       3         0                                   Miles, Mr. Frank    1
# 806       1         0                          Millet, Mr. Francis Davis    1
# 807       2         0                       Milling, Mr. Jacob Christian    1
# 808       1         0                        Minahan, Dr. William Edward    1
# 811       3         0                                   Mineff, Mr. Ivan    1
# 812       3         0                                 Minkoff, Mr. Lazar    1
# 813       3         0                              Mionoff, Mr. Stoytcho    1
# 814       2         0                        Mitchell, Mr. Henry Michael    1
# 815       3         0                                  Mitkoff, Mr. Mito    1
# 816       1         1                           Mock, Mr. Philipp Edmund    1
# 818       3         0                            Moen, Mr. Sigurd Hansen    1
# 819       1         0                         Molson, Mr. Harry Markland    1
# 820       2         0                              Montvila, Rev. Juozas    1
# ..      ...       ...                                                ...  ...
# 872       3         0                     Nieminen, Miss. Manta Josefina    0
# 874       3         1                        Nilsson, Miss. Berta Olivia    0
# 875       3         1                    Nilsson, Miss. Helmina Josefina    0
# 287       1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 864       1         1                            Newell, Miss. Madeleine    0
# 883       2         1                       Nye, Mrs. (Elizabeth Ramell)    0
# 884       3         1                           Nysten, Miss. Anna Sofia    0
# 284       1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...    0
# 283       1         1                            Crosby, Miss. Harriet R    0
# 888       3         1    O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)    0
# 280       3         1                           Cribb, Miss. Laura Alice    0
# 865       1         1                             Newell, Miss. Marjorie    0
# 298       3         0  Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria ...    0
# 835       3         1   Moubarek, Mrs. George (Omine "Amenia" Alexander)    0
# 843       3         1                        Murphy, Miss. Margaret Jane    0
# 836       3         1                     Moussa, Mrs. (Mantoura Boulos)    0
# 312       2         1                                  Davis, Miss. Mary    0
# 839       3         1                   Mullens, Miss. Katherine "Katie"    0
# 840       3         1                          Mulvihill, Miss. Bertha E    0
# 311       2         1  Davies, Mrs. John Morgan (Elizabeth Agnes Mary...    0
# 842       3         1                     Murphy, Miss. Katherine "Kate"    0
# 844       3         1                                 Murphy, Miss. Nora    0
# 300       1         1                               Daniels, Miss. Sarah    0
# 848       3         1                   Najib, Miss. Adele Kiamie "Jane"    0
# 849       3         1                        Nakid, Miss. Maria ("Mary")    0
# 851       3         1              Nakid, Mrs. Said (Waika "Mary" Mowad)    0
# 304       1         1               Davidson, Mrs. Thornton (Orian Hays)    0
# 856       2         1                Nasser, Mrs. Nicholas (Adele Achem)    0
# 858       3         0                             Naughton, Miss. Hannah    0
# 654       3         0          Khalil, Mrs. Betros (Zahie "Maria" Elias)    0
#
#       age  sibsp  parch      ticket      fare  cabin embarked boat   body  \
# 0    42.0      0      0   C.A. 5547    7.5500    NaN        S  NaN    NaN
# 726  61.0      0      0      235509   12.3500    NaN        Q  NaN    NaN
# 777   NaN      0      0      367228    7.7500    NaN        Q  NaN    NaN
# 780   NaN      2      0      367226   23.2500    NaN        Q   16    NaN
# 781  32.0      0      0      237216   13.5000    NaN        S  NaN  209.0
# 782  30.0      0      0      233478   13.0000    NaN        S  NaN    NaN
# 784   NaN      0      0       36568   15.5000    NaN        Q  NaN    NaN
# 785  36.0      0      0    PC 17473   26.2875    E25        S    7    NaN
# 789  46.0      0      0       28403   26.0000    NaN        S  NaN    NaN
# 790   NaN      0      0      370372    7.7500    NaN        Q  NaN    NaN
# 791  24.0      1      0      376566   16.1000    NaN        S  NaN    NaN
# 798  19.0      0      0   SW/PP 751   10.5000    NaN        S    B    NaN
# 799  55.5      0      0  A.5. 11206    8.0500    NaN        S  NaN  201.0
# 800   NaN      0      0      368703    7.7500    NaN        Q  NaN    NaN
# 801  39.0      0      0      248723   13.0000    NaN        S  NaN    NaN
# 802  28.0      1      0    PC 17604   82.1708    NaN        C  NaN    NaN
# 804  21.0      0      0      345501    7.7750    NaN        S   15    NaN
# 805   NaN      0      0      359306    8.0500    NaN        S  NaN    NaN
# 806  65.0      0      0       13509   26.5500    E38        S  NaN  249.0
# 807  48.0      0      0      234360   13.0000    NaN        S  NaN  271.0
# 808  44.0      2      0       19928   90.0000    C78        Q  NaN  230.0
# 811  24.0      0      0      349233    7.8958    NaN        S  NaN    NaN
# 812  21.0      0      0      349211    7.8958    NaN        S  NaN    NaN
# 813  28.0      0      0      349207    7.8958    NaN        S  NaN    NaN
# 814  70.0      0      0  C.A. 24580   10.5000    NaN        S  NaN    NaN
# 815   NaN      0      0      349221    7.8958    NaN        S  NaN    NaN
# 816  30.0      1      0       13236   57.7500    C78        C   11    NaN
# 818  25.0      0      0      348123    7.6500  F G73        S  NaN  309.0
# 819  55.0      0      0      113787   30.5000    C30        S  NaN    NaN
# 820  27.0      0      0      211536   13.0000    NaN        S  NaN    NaN
# ..    ...    ...    ...         ...       ...    ...      ...  ...    ...
# 872  29.0      0      0     3101297    7.9250    NaN        S  NaN    NaN
# 874  18.0      0      0      347066    7.7750    NaN        S    D    NaN
# 875  26.0      0      0      347470    7.8542    NaN        S   13    NaN
# 287  38.0      1      0    PC 17599   71.2833    C85        C    4    NaN
# 864  31.0      1      0       35273  113.2750    D36        C    6    NaN
# 883  29.0      0      0  C.A. 29395   10.5000    F33        S   11    NaN
# 884  22.0      0      0      347081    7.7500    NaN        S   13    NaN
# 284  64.0      1      1      112901   26.5500    B26        S    7    NaN
# 283  36.0      0      2   WE/P 5735   71.0000    B22        S    7    NaN
# 888   NaN      1      0      370365   15.5000    NaN        Q  NaN    NaN
# 280  17.0      0      1      371362   16.1000    NaN        S   12    NaN
# 865  23.0      1      0       35273  113.2750    D36        C    6    NaN
# 298  28.0      1      1      347080   14.4000    NaN        S  NaN    NaN
# 835   NaN      0      2        2661   15.2458    NaN        C    C    NaN
# 843   NaN      1      0      367230   15.5000    NaN        Q   16    NaN
# 836   NaN      0      0        2626    7.2292    NaN        C  NaN    NaN
# 312  28.0      0      0      237668   13.0000    NaN        S   13    NaN
# 839   NaN      0      0       35852    7.7333    NaN        Q   16    NaN
# 840  24.0      0      0      382653    7.7500    NaN        Q   15    NaN
# 311  48.0      0      2  C.A. 33112   36.7500    NaN        S   14    NaN
# 842   NaN      1      0      367230   15.5000    NaN        Q   16    NaN
# 844   NaN      0      0       36568   15.5000    NaN        Q   16    NaN
# 300  33.0      0      0      113781  151.5500    NaN        S    8    NaN
# 848  15.0      0      0        2667    7.2250    NaN        C    C    NaN
# 849   1.0      0      2        2653   15.7417    NaN        C    C    NaN
# 851  19.0      1      1        2653   15.7417    NaN        C    C    NaN
# 304  27.0      1      2  F.C. 12750   52.0000    B71        S    3    NaN
# 856  14.0      1      0      237736   30.0708    NaN        C  NaN    NaN
# 858   NaN      0      0      365237    7.7500    NaN        Q  NaN    NaN
# 654   NaN      1      0        2660   14.4542    NaN        C  NaN    NaN
#
#                                         home.dest
# 0                                             NaN
# 726                                           NaN
# 777                                           NaN
# 780                                           NaN
# 781                             Sydney, Australia
# 782                                    Sarnia, ON
# 784                                           NaN
# 785                              Philadelphia, PA
# 789                                 Rochester, NY
# 790                                           NaN
# 791                                           NaN
# 798                               Chelsea, London
# 799                                           NaN
# 800                                           NaN
# 801                 Harrow-on-the-Hill, Middlesex
# 802                                  New York, NY
# 804                                           NaN
# 805                                           NaN
# 806                          East Bridgewater, MA
# 807                           Copenhagen, Denmark
# 808                               Fond du Lac, WI
# 811                                           NaN
# 812                                           NaN
# 813                                           NaN
# 814  Guernsey / Montclair, NJ and/or Toledo, Ohio
# 815                                           NaN
# 816                                  New York, NY
# 818                                           NaN
# 819                                  Montreal, PQ
# 820                                 Worcester, MA
# ..                                            ...
# 872                                           NaN
# 874                                           NaN
# 875                                           NaN
# 287                                  New York, NY
# 864                                 Lexington, MA
# 883                Folkstone, Kent / New York, NY
# 884                                           NaN
# 284                                 Milwaukee, WI
# 283                                 Milwaukee, WI
# 888                                           NaN
# 280               Bournemouth, England Newark, NJ
# 865                                 Lexington, MA
# 298                                   Stanton, IA
# 835                                           NaN
# 843                                           NaN
# 836                                           NaN
# 312                    London / Staten Island, NY
# 839                                           NaN
# 840                                           NaN
# 311               St Ives, Cornwall / Hancock, MI
# 842                                           NaN
# 844                                           NaN
# 300                                           NaN
# 848                                           NaN
# 849                                           NaN
# 851                                           NaN
# 304                                  Montreal, PQ
# 856                                  New York, NY
# 858                                           NaN
# 654                                           NaN
#
# [1305 rows x 14 columns]

# %% [markdown]
# As indicated above, the sex column has been replaced with 0s and 1s.

# %%
import statsmodels.formula.api as smf
formula = 'survived ~ sex + age + fare'
model = smf.logit(formula, data=titanic)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.509606
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               survived   No. Observations:                 1042
# Model:                          Logit   Df Residuals:                     1038
# Method:                           MLE   Df Model:                            3
# Date:                Fri, 29 Nov 2019   Pseudo R-squ.:                  0.2454
# Time:                        10:14:45   Log-Likelihood:                -531.01
# converged:                       True   LL-Null:                       -703.72
#                                         LLR p-value:                 1.470e-74
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0232      0.196      5.229      0.000       0.640       1.407
# sex           -2.3572      0.155    -15.180      0.000      -2.662      -2.053
# age           -0.0111      0.005     -2.053      0.040      -0.022      -0.001
# fare           0.0099      0.002      5.242      0.000       0.006       0.014
# ==============================================================================
# """

# %% [markdown]
# All of our model variables are statistically significant because the p-values are all below 0.05.  Our R^2, however, is only 0.245, which is quite low.

# %% [markdown]
# In order to plug my personal information into the model, I need to come up with a fare value.  Currently, a 7-day Transatlantic cruise costs about $1500 for a basic cabin.  Using the CPI inflation calculator (http://www.in2013dollars.com/2019-dollars-in-1912?amount=1500) a $1500 ticket would have cost me $56.80 in 1912.  Now, converting that to British Pounds, the fare I would have paid for my Titanic ticket in 1912 would be 45.47 British Pounds.

# %%
#To make a prediction, we have to extract the exogenous and endogenous variables.
endog = pd.DataFrame(model.endog, columns=[model.endog_names])
exog = pd.DataFrame(model.exog, columns=model.exog_names)

# %%
#The baseline prediction strategy is to guess "survived". In that case, we're right almost 41% of the time.
actual = endog['survived']
baseline = actual.mean()
baseline
# Out:
# 0.4059500959692898

# %%
#If we use the previous model, we can compute the number of predictions we get right.
predict = (results.predict() >= 0.5)
true_pos = predict * actual
true_neg = (1 - predict) * (1 - actual)
sum(true_pos), sum(true_neg)
# Out:
# (292.0, 514.0)

# %%
#And the accuracy, which is quite a bit higher than the baseline.
acc = (sum(true_pos) + sum(true_neg)) / len(actual)
acc
# Out:
# 0.7735124760076776

# %%
#Inputting my personal information into the model
columns = ['sex', 'age', 'fare']
new = pd.DataFrame([[0, 72, 6.06]], columns=columns)
y = results.predict(new)
y
# Out:
# 0    0.57012
# dtype: float64

# %% [markdown]
# After all is said and done, it looks like I would have died on the Titanic with only a 20% chance of survival.
